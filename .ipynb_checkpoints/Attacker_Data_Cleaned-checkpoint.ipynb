# %%
 # Dependencies
import pandas as pd

# Make a reference to the books.csv file path
f17path = "/newdata/FIFA17.csv"
f18path = "/newdata/FIFA18.csv"
f19path = "/newdata/FIFA19.csv"

# Import the books.csv file as a DataFrame
read17 = pd.read_csv(f17path, encoding="UTF-8")
read18 = pd.read_csv(f18path, encoding="UTF-8")
read19 = pd.read_csv(f19path, encoding="UTF-8")

# %%
# Get Attackers
# Put DOB for 17 and 18 in same format
read17['Birth_Date'] = read17['Birth_Date'].str.replace('/', '-', regex=True)

# Find Attackers for each league
# FIFA17
attacker17 = []
for posit in read17["Preffered_Position"]:
    if ("ST" in posit) == True:
        attacker17.append(True)
    elif ("CF" in posit) == True:
        attacker17.append(True)
    elif ("RW" in posit) == True:
        attacker17.append(True)
    elif ("LW" in posit) == True:
        attacker17.append(True)        
    else:
        attacker17.append(False)
read17['attacker'] = attacker17
att17 = read17.loc[read17["attacker"] == True, :]

lname17 = []
for name in att17['Name']:
    lname17.append(name.split(" ")[-1])

att17['Last_Name'] = lname17

# FIFA18
att18 = read18.loc[((read18["prefers_rw"] == True) | (read18["prefers_lw"] == True) | (read18["prefers_st"] == True) | (read18["prefers_cf"] == True) | (read18["prefers_lw"] == True)) == True]

lname18 = []
for name in att18['name']:
    lname18.append(name.split(" ")[-1])

att18['Last_Name'] = lname18    
    
# FIFA19
attacker19 = []
for pos in read19["Position"]:
    if pos == "ST":
        attacker19.append(True)
    elif pos == "CF":
        attacker19.append(True)
    elif pos == "CAM":
        attacker19.append(True)
    elif pos == "RF":
        attacker19.append(True) 
    elif pos == "RAM":
        attacker19.append(True) 
    elif pos == "RS":
        attacker19.append(True)  
    elif pos == "RW":
        attacker19.append(True)
    elif pos == "RM":
        attacker19.append(True)
    elif pos == "LF":
        attacker19.append(True)
    elif pos == "LS":
        attacker19.append(True) 
    elif pos == "LW":
        attacker19.append(True)
    elif pos == "LAM":
        attacker19.append(True) 
    elif pos == "LM":
        attacker19.append(True) 
    else:
        attacker19.append(False)

read19['attacker'] = attacker19
att19 = read19.loc[read19["attacker"] == True]

# %%
# Select columns from each 
# FIFA 17
att17df  = att17[['Name','Last_Name','Birth_Date','Club','Rating','Attacking_Position','Finishing','Shot_Power','Long_Shots','Volleys','Penalties','Vision','Crossing','Freekick_Accuracy','Short_Pass','Long_Pass','Curve']]
att17df = att17df.rename(columns={'Club':'Club_2017',"Rating":"Rating_2017",'Attacking_Position':'Positioning_2017','Finishing':'Finishing_2017','Shot_Power':'Shot_Power_2017','Long_Shots':'Long_Shots_2017','Volleys':'Volleys_2017','Penalties':'Penalties_2017','Vision':'Vision_2017','Crossing':'Crossing_2017','Freekick_Accuracy':'FKAccuracy_2017','Short_Pass':'Short_Pass_2017','Long_Pass':'Long_Pass_2017','Curve':'Curve_2017'})

# FIFA 18
#'name':'Name', (maybe need to add back to 18df)
# need to interpret preferred position from the true/false fields for 18, fix birth dates to match 17
att18df  = att18[['name','Last_Name','ID','club','overall','positioning','finishing','shot_power','long_shots','volleys','penalties','volleys','penalties','vision','crossing','free_kick_accuracy','short_passing','long_passing','curve']]
att18df = att18df.rename(columns={'club':'Club_2018','overall':'Overall_2018','positioning':'Positioning_2018','finishing':'Finishing_2018','shot_power':'Shot_Power_2018','long_shots':'Long_Shots_2018','volleys':'Volleys_2018','penalties':'Penalties_2018','volleys':'Volleys_2018','penalties':'Penalties_2018','vision':'Vision_2018','crossing':'Crossing_2018','free_kick_accuracy':'FKAccuracy_2018','short_passing':'Short_Pass_2018','long_passing':'Long_Pass_2018','curve':'Curve_2018'})

birth = []
for date in att18['birth_date']:
    split = date.split("-")
    newdate = split[1]+"-"+split[2]+"-"+split[0]
    birth.append(newdate)

att18df['Birth_Date'] = birth

# FIFA 19
# need to interpret preferred position from the true/false fields for 18
att19df = att19[['Name','ID','Club','Overall','Positioning','Finishing','ShotPower','LongShots','Volleys','Penalties','Vision','Crossing','FKAccuracy','ShortPassing','LongPassing','Curve']]
att19df = att19df.rename(columns={'Club':'Club_2019','Overall':'Overall_2019','Positioning':'Positioning_2019','Finishing':'Finishing_2019','ShotPower':'Shot_Power_2019','LongShots':'Long_Shots_2019','Volleys':'Volleys_2019','Penalties':'Penalties_2019','Vision':'Vision_2019','Crossing':'Crossing_2019','FKAccuracy':'FKAccuracy_2019','ShortPassing':'Short_Pass_2019','LongPassing':'Long_Pass_2019','Curve':'Curve_2019'})

# %%
# Merge into DF
attackers0 = pd.merge(att17df, att18df, on=['Birth_Date','Last_Name'], how='outer')
attackers0 = attackers0.dropna()
attackers = pd.merge(attackers0, att19df, on="ID", how='outer')
attackers = attackers.dropna()
# Out:
#                             Name  Birth_Date                 Club  \
# 0              Cristiano Ronaldo  02-05-1985          Real Madrid
# 1                   Lionel Messi  06-24-1987         FC Barcelona
# 2                         Neymar  02-05-1992         FC Barcelona
# 3                   Luis SuÃ¡rez  01-24-1987         FC Barcelona
# 6             Robert Lewandowski  08-21-1988            FC Bayern
# 7                    Gareth Bale  07-16-1989          Real Madrid
# 8            Zlatan IbrahimoviÄ  10-03-1981       Manchester Utd
# 11                   Eden Hazard  01-07-1991              Chelsea
# 13                   Mesut Ãzil  10-15-1988              Arsenal
# 14              Gonzalo HiguaÃ­n  12-10-1987             Juventus
# 17                Sergio AgÃ¼ero  06-02-1988      Manchester City
# 19             Antoine Griezmann  03-21-1991     AtlÃ©tico Madrid
# 22               Alexis SÃ¡nchez  12-19-1988              Arsenal
# 35     Pierre-Emerick Aubameyang  06-18-1989        Bor. Dortmund
# 42                  Arjen Robben  01-23-1984            FC Bayern
# 43                  Paulo Dybala  11-15-1993             Juventus
# 48                Thomas MÃ¼ller  09-13-1989            FC Bayern
# 52                      Coutinho  06-12-1992            Liverpool
# 53              Ãngel Di MarÃ­a  02-14-1988                  PSG
# 54                   Diego Costa  10-07-1988              Chelsea
# 55                Edinson Cavani  02-14-1987                  PSG
# 60                 Karim Benzema  12-19-1987          Real Madrid
# 62                Franck RibÃ©ry  04-07-1983            FC Bayern
# 65                    Harry Kane  07-28-1993                Spurs
# 66           Alexandre Lacazette  05-28-1991       Olym. Lyonnais
# 68                 Romelu Lukaku  05-13-1993              Everton
# 76                 Dimitri Payet  03-29-1987      Olym. Marseille
# 77                 Dries Mertens  05-06-1987               Napoli
# 86              Yannick Carrasco  09-04-1993     AtlÃ©tico Madrid
# 90                  Mauro Icardi  02-19-1993                Inter
# ...                          ...         ...                  ...
# 17343               Scott McLean  08-30-1997           Kilmarnock
# 17350           Michael O'Connor  07-31-1998      Shamrock Rovers
# 17353            Victor Arboleda  01-01-1997             Portland
# 17356               Jesse Devers  01-11-1997        Galway United
# 17364               Connor Smith  10-14-1996           Hartlepool
# 17365        Alexander Gilchrist  03-03-1995        St. Johnstone
# 17369         Kofi Yeboah Schulz  07-21-1989        FC St. Gallen
# 17371                  Dean Ebbe  07-16-1994         Inverness CT
# 17378              Cathal Farren  07-02-1998           Derry City
# 17396                  Ryan Loft  09-14-1997            Stevenage
# 17403                 Jamie Gray  04-13-1998            Stevenage
# 17411                Nathan Webb  07-09-1998           Accrington
# 17423               Cody Mulhall  08-25-1996        Longford Town
# 17438          Teruhito Nakagawa  07-27-1992  Yokohama F. Marinos
# 17441           Tomoya Koyamatsu  04-24-1995               Nagoya
# 17458           Victor Adeboyejo  01-12-1998        Leyton Orient
# 17467             Dylan McCroary  07-27-1998           Finn Harps
# 17474              Jordan Graham  12-30-1997        Oxford United
# 17475              Adonijah Reid  08-13-1999            FC Dallas
# 17484                 Deon Moore  05-14-1999         Peterborough
# 17490             Omer Dzonlagic  05-25-1995              FC Thun
# 17511               Assan Ceesay  03-17-1994            FC Lugano
# 17512             Marcus Harness  02-24-1996        Burton Albion
# 17519                Eoin Porter  06-10-1999       Wexford Youths
# 17538                   Cian Fay  07-20-1998        Longford Town
# 17539              Karl Chambers  06-07-1996        Longford Town
# 17546              Ollie Bassett  03-06-1998          Yeovil Town
# 17564               Kaylen Hinds  01-21-1998            Stevenage
# 17566            Neil McLaughlin  01-01-1998      Partick Thistle
# 17579                  Sam Dalby  12-07-1999        Leyton Orient
#
#       Preffered_Position  Rating  Attacking_Position  Finishing  Shot_Power  \
# 0                  LW/ST      94                  94         93          92
# 1                     RW      93                  93         95          85
# 2                     LW      92                  90         89          78
# 3                     ST      92                  92         94          87
# 6                     ST      90                  89         91          86
# 7                     RW      90                  86         87          91
# 8                     ST      90                  86         90          93
# 11                 LW/LM      89                  85         81          79
# 13                CAM/LW      89                  84         75          70
# 14                    ST      89                  92         92          86
# 17                    ST      89                  91         90          87
# 19                 ST/LW      88                  91         88          81
# 22                 ST/RM      88                  86         85          84
# 35                 ST/RM      87                  89         88          81
# 42                 RM/RW      87                  85         84          86
# 43                ST/CAM      86                  85         88          82
# 48             CF/CAM/ST      86                  93         87          77
# 52                LW/CAM      86                  83         73          79
# 53                RW/CAM      86                  82         74          87
# 54                    ST      86                  88         89          84
# 55                    ST      86                  89         85          85
# 60                    ST      86                  87         87          83
# 62                 LM/LW      86                  81         76          76
# 65                    ST      85                  86         88          86
# 66                    ST      85                  87         87          81
# 68                    ST      85                  85         87          88
# 76                 LM/LW      85                  79         76          78
# 77                 LW/ST      85                  81         77          80
# 86                 LM/LW      84                  82         78          84
# 90                    ST      84                  89         89          81
# ...                  ...     ...                 ...        ...         ...
# 17343                 ST      51                  48         52          52
# 17350                 ST      51                  47         57          47
# 17353              RW/CF      51                  53         49          49
# 17356                 ST      51                  47         50          57
# 17364                 ST      51                  47         41          46
# 17365              CB/ST      51                  54         55          51
# 17369              LW/LB      51                  44         57          71
# 17371                 ST      51                  49         50          46
# 17378                 ST      50                  53         50          46
# 17396                 ST      50                  52         56          46
# 17403                 ST      50                  53         55          42
# 17411                 ST      50                  49         54          43
# 17423                 ST      50                  46         53          42
# 17438                 RW      50                  53         61          51
# 17441              CF/LM      50                  47         59          50
# 17458                 ST      50                  47         55          47
# 17467              LW/ST      49                  48         47          47
# 17474              RW/ST      49                  47         49          56
# 17475                 ST      49                  51         56          44
# 17484                 ST      49                  42         47          52
# 17490                 RW      49                  41         52          61
# 17511              RW/ST      49                  50         48          64
# 17512              RM/RW      49                  45         53          66
# 17519                 ST      48                  47         52          48
# 17538                 ST      48                  48         45          43
# 17539                 ST      48                  49         52          44
# 17546                 ST      48                  48         47          47
# 17564                 CF      47                  48         52          48
# 17566             ST/CAM      47                  44         47          48
# 17579                 ST      45                  48         48          42
#
#        Long_Shots  Volleys  Penalties
# 0              90       88         85
# 1              88       85         74
# 2              77       83         81
# 3              86       88         85
# 6              82       86         81
# 7              90       76         76
# 8              88       93         91
# 11             82       79         86
# 13             76       77         67
# 14             80       88         70
# 17             84       85         80
# 19             82       87         71
# 22             81       83         77
# 35             79       86         82
# 42             88       86         80
# 43             88       88         84
# 48             80       83         60
# 52             85       75         64
# 53             79       77         73
# 54             72       82         76
# 55             78       84         84
# 60             77       79         82
# 62             73       80         78
# 65             80       70         82
# 66             74       82         84
# 68             76       76         80
# 76             83       79         76
# 77             81       70         78
# 86             75       68         74
# 90             70       81         78
# ...           ...      ...        ...
# 17343          43       41         55
# 17350          47       39         52
# 17353          42       33         57
# 17356          48       38         61
# 17364          39       41         41
# 17365          50       49         53
# 17369          41       42         52
# 17371          49       49         57
# 17378          45       44         51
# 17396          45       38         49
# 17403          42       36         60
# 17411          47       31         64
# 17423          46       36         54
# 17438          52       36         64
# 17441          49       52         52
# 17458          47       34         58
# 17467          37       41         47
# 17474          33       42         50
# 17475          45       36         62
# 17484          41       44         56
# 17490          37       43         50
# 17511          42       43         53
# 17512          40       40         50
# 17519          42       37         57
# 17538          44       36         59
# 17539          44       32         58
# 17546          45       42         49
# 17564          47       36         62
# 17566          30       41         39
# 17579          44       35         40
#
# [4131 rows x 11 columns]

# %%
attackers.to_csv ("attackers.csv", index = None, header=True)
attackers0.to_csv ("attackers0.csv", index = None, header=True)
